# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

sns.set()

# %%
data = pd.read_csv("dados_anuncios_airbnb.csv")

# %%
data.head()
# Out:
#                                              Título  Preço (R$)  Avaliação  \
# 0        FLAT PARTICULAR NO MELIA  - AV. IBIRAPUERA         110       4.90
# 1      Studio novinho a 300 m metrô - Self check in         117       4.80
# 2   Studio encantador em São Paulo próximo ao metrô         110       4.87
# 3  Flat mobiliado ao lado do Hospital Sirio Libanês          80       4.61
# 4       Suíte moderna com cama de casal no Brooklin          54       4.89
#
#          Bairro               Imóvel  \
# 0  Indianópolis         Flat inteiro
# 1    Consolacao  Apartamento inteiro
# 2    Consolacao         Flat inteiro
# 3    Bela Vista         Flat inteiro
# 4  Vila Olímpia       Quarto inteiro
#
#                                      Características
# 0  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 1  ['5 hóspedes', 'Estúdio', '3 camas', '1 banhei...
# 2  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 3  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 4  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Título           350 non-null    object
#  1   Preço (R$)       350 non-null    int64
#  2   Avaliação        297 non-null    float64
#  3   Bairro           350 non-null    object
#  4   Imóvel           350 non-null    object
#  5   Características  350 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 16.5+ KB

# %%
# dados nulos
data.loc[data['Avaliação'].isnull(), :]
# Out:
#                                                 Título  Preço (R$)  Avaliação  \
# 7         Apto Jardins mobiliado Excelente localização          75        NaN
# 19   Apartamento no Bom Retiro 5min da Rodoviária T...          43        NaN
# 27    APARTAMENTO 02-50M²- 10 MINUTOS DO AEROPORTO GRU         100        NaN
# 28                            La Residence Alamada Jau          91        NaN
# 44   Apartamento agradável e bem iluminado. V. Pompéia         111        NaN
# 46               FIQUE PRÓXIMO AO PARQUE DO IBIRAPUERA          99        NaN
# 48                     #208 - Cyclinn Faria Lima Itaim         182        NaN
# 84                    FLAT 104 MARAVILHOSO NOS JARDINS         135        NaN
# 93    Flat com serviços - Hosp. Sírio Libanês/Paulista          98        NaN
# 98               FIQUE PRÓXIMO AO PARQUE DO IBIRAPUERA          99        NaN
# 99                    FLAT 104 MARAVILHOSO NOS JARDINS         135        NaN
# 114                                 Victoria Place 105         106        NaN
# 129                 HOSPEDAGEM RODEADA DE ÁREAS VERDES          99        NaN
# 131         Flat na Bela Cintra by Atlantica Residence         127        NaN
# 135                   FLAT 104 MARAVILHOSO NOS JARDINS         135        NaN
# 141     Apto. completo, aconchegante e bem localizado.          80        NaN
# 145               Quarto mobiliado em local tranquilo.          56        NaN
# 148                 HOSPEDAGEM RODEADA DE ÁREAS VERDES          99        NaN
# 164                   FLAT 804 MARAVILHOSO NOS JARDINS         150        NaN
# 171                   Studio Casal Mobiliado - Butantã          90        NaN
# 175  Apartamento inteiro próximo ao Mackenzie com w...         100        NaN
# 183  Estúdio Mobiliado com Varanda, Smart-TV e Wi-Fi !          98        NaN
# 189                 HOSPEDAGEM RODEADA DE ÁREAS VERDES          99        NaN
# 191  Flat c/Sacada - Região  Ibirapuera próximo UNI...         100        NaN
# 193  Kit para 1 pessoa com ar cond a 300m do metrô Ap2          60        NaN
# 196              Itaim Bibi Address Faria Lima Casal 3          90        NaN
# 199         Flat Imperdível Vila Clementino/Ibirapuera          96        NaN
# 208    Suíte mobiliada c/ copa e Wi-Fi próx ao hosp SP          65        NaN
# 209                Loft top no coração da Vila Olimpia         149        NaN
# 214  Apartamento Moderno Mobiliado com Cooktop e Wi-Fi          85        NaN
# 224             Lindo AP, 73m2 próximo ao metrô Saúde!         120        NaN
# 225    Suíte mobiliada c/ copa e Wi-Fi próx ao hosp SP          65        NaN
# 227     Quartos 3 individuais em Ap centro SP com wifi          54        NaN
# 229                                   São Paulo Centro          73        NaN
# 231                            Coliving Petit Paris 14          55        NaN
# 233         Apto completo a 30m do metrô Santa Cecília         120        NaN
# 241                              Flat de Luxo em Moema         155        NaN
# 242   Pacote MENSAL! Flat no Hotel Quality SP Jardins!         115        NaN
# 243                             OFERTA FLAT R. INDIANA          88        NaN
# 244    suíte grande  em vila privativa na Vila Olimpia          65        NaN
# 259                 HOSPEDAGEM RODEADA DE ÁREAS VERDES          99        NaN
# 263         Flat na Bela Cintra by Atlantica Residence         127        NaN
# 274               loft completo, excelente localizaçao         119        NaN
# 276  Studio na Vila Nova Conceição, próx Pq. Ibirap...         131        NaN
# 284   Apto 5  ideal para 1 pessoa px metrô imigrantes.          54        NaN
# 286  Studio coração da V. Olímpia Próx ao Insper Wi-Fi         145        NaN
# 293                          Apto seguro e confortável          89        NaN
# 301                   Studio Casal Mobiliado - Butantã          90        NaN
# 319    Studio Descolado na Sé / Liberdade em Sao Paulo          80        NaN
# 329   Apto 5  ideal para 1 pessoa px metrô imigrantes.          54        NaN
# 331  Studio coração da V. Olímpia Próx ao Insper Wi-Fi         145        NaN
# 338                          Apto seguro e confortável          89        NaN
# 346                   Studio Casal Mobiliado - Butantã          90        NaN
#
#                   Bairro                    Imóvel  \
# 7                Paraíso       Apartamento inteiro
# 19            Bom Retiro            Quarto inteiro
# 27          Vila Florida        Condomínio inteiro
# 28       Cerqueira César              Flat inteiro
# 44           Água Branca       Apartamento inteiro
# 46       Vila Uberabinha            Quarto inteiro
# 48            Itaim Bibi       Apartamento inteiro
# 84       Cerqueira César              Flat inteiro
# 93            Bela Vista              Flat inteiro
# 98       Vila Uberabinha            Quarto inteiro
# 99       Cerqueira César              Flat inteiro
# 114           Itaim Bibi       Apartamento inteiro
# 129      Vila Uberabinha            Quarto inteiro
# 131                 flat                    Quarto
# 135      Cerqueira César              Flat inteiro
# 141           Bela Vista        Condomínio inteiro
# 145              Santana            Quarto inteiro
# 148      Vila Uberabinha            Quarto inteiro
# 164      Cerqueira César              Flat inteiro
# 171             Ferreira        Condomínio inteiro
# 175         Vila Buarque       Apartamento inteiro
# 183               Centro        Condomínio inteiro
# 189      Vila Uberabinha            Quarto inteiro
# 191      Vila Clementino              Flat inteiro
# 193             Ipiranga       Apartamento inteiro
# 196           Itaim Bibi              Flat inteiro
# 199      Vila Clementino              Flat inteiro
# 208      Vila Clementino  Suíte de visitas inteira
# 209         Vila Olímpia              Loft inteiro
# 214       Santa Efigênia        Condomínio inteiro
# 224                Saúde       Apartamento inteiro
# 225      Vila Clementino  Suíte de visitas inteira
# 227               Centro            Quarto inteiro
# 229            República       Apartamento inteiro
# 231           Bela Vista            Quarto inteiro
# 233            República       Apartamento inteiro
# 241         Indianópolis              Flat inteiro
# 242      Jardim Paulista              Flat inteiro
# 243         Vila Olímpia              Flat inteiro
# 244         Vila Olímpia            Quarto inteiro
# 259      Vila Uberabinha            Quarto inteiro
# 263                 flat                    Quarto
# 274           Itaim Bibi              Loft inteiro
# 276  Vila Nova Conceição       Apartamento inteiro
# 284  Vila Firmiano Pinto        Condomínio inteiro
# 286         Vila Olímpia              Loft inteiro
# 293                 Brás        Condomínio inteiro
# 301             Ferreira        Condomínio inteiro
# 319                   Sé       Apartamento inteiro
# 329  Vila Firmiano Pinto        Condomínio inteiro
# 331         Vila Olímpia              Loft inteiro
# 338                 Brás        Condomínio inteiro
# 346             Ferreira        Condomínio inteiro
#
#                                        Características
# 7    ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 19   ['2 hóspedes', '2 quartos', '1 cama', '1 banhe...
# 27   ['4 hóspedes', '1 quarto', '2 camas', '1 banhe...
# 28   ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 44   ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 46   ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 48   ['4 hóspedes', '1 quarto', '3 camas', '1 banhe...
# 84   ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 93   ['2 hóspedes', '1 quarto', '3 camas', '1 banhe...
# 98   ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 99   ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 114  ['2 hóspedes', '1 quarto', '0 camas', '1 banhe...
# 129  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 131  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 135  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 141  ['3 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 145  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 148  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 164  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 171  ['2 hóspedes', '1 quarto', '1 banheiro', 'Wi-F...
# 175  ['2 hóspedes', 'Estúdio', '2 camas', '1 banhei...
# 183  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 189  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 191  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 193  ['1 hóspede', 'Estúdio', '1 cama', '1 banheiro...
# 196  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 199  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 208  ['2 hóspedes', '1 quarto', '1 cama', '0 banhei...
# 209  ['2 hóspedes', 'Estúdio', '1 cama', '1 banheir...
# 214  ['2 hóspedes', 'Estúdio', '1 cama', '1 banheir...
# 224  ['4 hóspedes', '2 quartos', '2 camas', '1 banh...
# 225  ['2 hóspedes', '1 quarto', '1 cama', '0 banhei...
# 227  ['1 hóspede', '4 quartos', '1 cama', '2 banhei...
# 229  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 231  ['1 hóspede', '1 quarto', '1 cama', '1 banheir...
# 233  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 241  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 242  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 243  ['2 hóspedes', '1 quarto', '2 camas', '1 banhe...
# 244  ['3 hóspedes', '1 quarto', '1 cama', '2 banhei...
# 259  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 263  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 274  ['4 hóspedes', '1 quarto', '2 camas', '1 banhe...
# 276  ['2 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 284  ['1 hóspede', 'Estúdio', '1 cama', '1 banheiro...
# 286  ['2 hóspedes', 'Estúdio', '1 cama', '1 banheir...
# 293  ['4 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 301  ['2 hóspedes', '1 quarto', '1 banheiro', 'Wi-F...
# 319  ['2 hóspedes', 'Estúdio', '1 cama', '1 banheir...
# 329  ['1 hóspede', 'Estúdio', '1 cama', '1 banheiro...
# 331  ['2 hóspedes', 'Estúdio', '1 cama', '1 banheir...
# 338  ['4 hóspedes', '1 quarto', '1 cama', '1 banhei...
# 346  ['2 hóspedes', '1 quarto', '1 banheiro', 'Wi-F...

# %%
data.columns
# Out:
# Index(['Título', 'Preço (R$)', 'Avaliação', 'Bairro', 'Imóvel',
#        'Características'],
#       dtype='object')

# %%
plt.figure(figsize = (12,6))
ax = sns.heatmap(data.describe().T, 
                 cmap = 'Blues', 
                annot = True, fmt = '.1f', 
                linewidths = 5, cbar = False, 
                annot_kws={"size": 16})
ax.set_title('Describe', fontsize = 18)
plt.xticks(size = 12)
plt.yticks(size = 12, rotation = 0);

# %%
ax = sns.distplot(data['Preço (R$)'])
ax.figure.set_size_inches(12,6)
ax.set_title('Histograma dos Preços', fontsize = 20)
ax.set_ylabel('Frequência')
ax.set_xlabel('Preço (R$)')
plt.show()

# %%
ax = sns.boxplot(data = data['Preço (R$)'], orient='h')
ax.figure.set_size_inches(12,6)
ax.set_title('Boxplot do Preço')
ax.set_xlabe

# %%
ax = sns.distplot(data['Avaliação'])
ax.figure.set_size_inches(12,6)
ax.set_title('Histograma da Avaliaçao', fontsize = 20)
ax.set_ylabel('Frequência')
ax.set_xlabel('Avaliação (0-5)')
plt.show()

# %%
ax = sns.boxplot(data = data['Avaliação'], orient='h')
ax.figure.set_size_inches(12,6)
ax.set_title('Boxplot da Avaliação');
